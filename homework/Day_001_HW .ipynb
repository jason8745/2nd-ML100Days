# %% [markdown]
# # DAY001 20190416

# %% [markdown]
# # 作業1

# %%
#Data: House Price Prediction
#1.你選的這組資料為何重要:這組資料是Kaggle上較適合新手挑戰的資料，且有許多人的Kernels可以參考，幫助自己建立完整的分析建模架構
#2.資料從何而來:The Ames Housing dataset was compiled by Dean De Cock for use in data science education
#3.蒐集而來的資料型態為何?:有浮點數、整數、以及類別型態的資料
#4.這組資料想解決的問題如何評估:資料的目標主要是透過Feature來預測房價，而最後我們會用RMSE來對我們的預測進行評估

# %% [markdown]
# # 作業2

# %%
#1.核心問題為:提高旗下載客車隊的載客量，及降低空車率
#2.資料從何而來:載客車隊的回傳數據，以及政府的open data，GPS回傳的資訊，都可以作為分析的資料
#3.蒐集而來的資料型態為何? : 依照蒐集的方法以及目的，會使的資料的型態不同
#4.你要回答的問題，其如何評估 : 透過數據分析，並建立預測模型，讓叫車的人能夠有最快叫到車的好體驗，另一方面，也指派離其最近的司機，透過這樣
#的進行方式，讓三方(平台方、車隊、乘客)都受益

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,y_hat):
    return sum(pow((y-y_hat),2))/len(y)

# %%
def mean_absolute_error(y,y_hat):
    return sum(abs(y-y_hat))/len(y)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 235.878
# The Mean absolute error is 11.627
